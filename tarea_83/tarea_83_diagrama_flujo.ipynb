# %% [markdown]
# # Diagrama de flujo calculo de un cuadrado con un lado conocido

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Implementación en código

# %%
l = 2 #se asigna un valor al lado
area = l*l #se calcula el área y se le asigna el valor a la variable
print (area)#se escribe el valor calculado de la variable
# Out:
# 4
